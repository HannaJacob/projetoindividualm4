# %% [markdown]
# <a href="https://colab.research.google.com/github/HannaJacob/projetoindividualm4/blob/main/Projeto_individual_M4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = "blue"> Análise do Progresso Semanal da Equipe de Desenvolvimento de Software 📊

# %% [markdown]
# ## 🔹 1. Importação de Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Nesta etapa, importamos as bibliotecas necessárias, incluindo pandas para manipulação de dados e matplotlib.pyplot para visualização.

# %% [markdown]
# ## 🔹 2. Dados Fornecidos

# %%
dados = {
    'Dia': ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado', 'Domingo'],
    'Horas_Trabalhadas': [6, 7, 8, 6, 7, 5, 4],
    'Bugs_Corrigidos': [3, 2, 1, 4, 3, 2, 1],
    'Tarefas_Concluidas': [5, 4, 6, 4, 5, 3, 2]
}

# %% [markdown]
# Definimos os dados fornecidos em um dicionário, onde as chaves representam os nomes das colunas e os valores são listas correspondentes.

# %% [markdown]
# ## 🔹 3. Criar DataFrame

# %%
df = pd.DataFrame(dados)

# %% [markdown]
# Criamos um DataFrame usando a biblioteca pandas para facilitar a manipulação dos dados.

# %% [markdown]
# ## 🔹 4. Adicionar Coluna de Produtividade Diária

# %%
df['Produtividade_Diaria'] = df['Tarefas_Concluidas'] / df['Horas_Trabalhadas']

# %% [markdown]
# Adicionamos uma nova coluna chamada 'Produtividade_Diaria', que representa o número de tarefas concluídas por hora.

# %% [markdown]
# ## 🔹 5. Calcular Métricas

# %%
total_horas_trabalhadas = df['Horas_Trabalhadas'].sum()
media_diaria_horas_trabalhadas = df['Horas_Trabalhadas'].mean()

total_bugs_corrigidos = df['Bugs_Corrigidos'].sum()
media_diaria_bugs_corrigidos = df['Bugs_Corrigidos'].mean()

total_tarefas_concluidas = df['Tarefas_Concluidas'].sum()
media_diaria_tarefas_concluidas = df['Tarefas_Concluidas'].mean()

# %% [markdown]
# Calculamos várias métricas, como total e média diária de horas trabalhadas, bugs corrigidos e tarefas concluídas.

# %% [markdown]
# ## 🔹 6. Imprimir Resultados

# %%
print(f'Total de Horas Trabalhadas: {total_horas_trabalhadas} horas')
print(f'Média Diária de Horas Trabalhadas: {media_diaria_horas_trabalhadas:.2f} horas')

print(f'Total de Bugs Corrigidos: {total_bugs_corrigidos} bugs')
print(f'Média Diária de Bugs Corrigidos: {media_diaria_bugs_corrigidos:.2f} bugs')

print(f'Total de Tarefas Concluídas: {total_tarefas_concluidas} tarefas')
print(f'Média Diária de Tarefas Concluídas: {media_diaria_tarefas_concluidas:.2f} tarefas')
# Out:
# Total de Horas Trabalhadas: 43 horas
# Média Diária de Horas Trabalhadas: 6.14 horas
# Total de Bugs Corrigidos: 16 bugs
# Média Diária de Bugs Corrigidos: 2.29 bugs
# Total de Tarefas Concluídas: 29 tarefas
# Média Diária de Tarefas Concluídas: 4.14 tarefas

# %% [markdown]
# Imprimimos os resultados das métricas calculadas para análise.

# %% [markdown]
# ## 🔹 7. Visualização

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(df['Dia'], df['Produtividade_Diaria'], marker='o', label='Produtividade Diária')
ax.set_title('Produtividade Diária (Tarefas Concluídas por Hora)')
ax.set_xlabel('Dia')
ax.set_ylabel('Tarefas Concluídas por Hora')
ax.legend()
plt.show()

# %% [markdown]
# Criamos um gráfico de linha para visualizar a produtividade diária, facilitando a interpretação dos resultados.
#
# Este notebook oferece uma análise abrangente do progresso semanal da equipe de desenvolvimento de software, desde a importação de dados até a visualização dos resultados.
